# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas Series exercises

# %%
# !pip install numpy pandas --quiet

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Print the pandas version and the configuration
print('numpy version: ' + str(np.__version__))
print('pandas version: ' + str(pd.__version__))
# Out:
# numpy version: 1.20.1
# pandas version: 1.2.2

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series creation

# %% [markdown]
# ### Create an empty pandas Series

# %%
# your code goes here
pd.Series()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Series([], dtype: float64)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X python list convert it to an Y pandas Series

# %%
# your code goes here
X = [1, 5, 7, 10, 15, 16, 17]
Y = pd.Series(X)
print(X, type(X))
print(Y, type(Y))
# Out:
# [1, 5, 7, 10, 15, 16, 17] <class 'list'>
# 0     1
# 1     5
# 2     7
# 3    10
# 4    15
# 5    16
# 6    17
# dtype: int64 <class 'pandas.core.series.Series'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, name it 'My letters'

# %%
# your code goes here
X = pd.Series(['L','O','K','E','S','H'], name='My letters')
X
# Out:
# 0    L
# 1    O
# 2    K
# 3    E
# 4    S
# 5    H
# Name: My letters, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its values

# %%
# your code goes here
X = pd.Series(['L','O','K','E','S','H'], name='My letters')
X.values
# Out:
# array(['L', 'O', 'K', 'E', 'S', 'H'], dtype=object)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series indexation

# %% [markdown]
# ### Assign index names to the given X pandas Series

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
X
# Out:
# One          1
# Two          2
# Three        3
# Five         5
# Seven        7
# Eleven      11
# Thirteen    13
# Name: First 7 Prime Numbers, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its first element

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
print(X[0]) #by position
print(X.iloc[0]) #by position
print(X['One']) #by index
# Out:
# 1
# 1
# 1

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its last element

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
print(X[-1]) #by position
print(X.iloc[-1]) #by position
print(X['Thirteen']) #by index
# Out:
# 13
# 13
# 13

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show all middle elements

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
print(X[1:-1]) #by position
print(X.iloc[1:-1]) #by position
# Out:
# Two        2
# Three      3
# Five       5
# Seven      7
# Eleven    11
# Name: First 7 Prime Numbers, dtype: int64
# Two        2
# Three      3
# Five       5
# Seven      7
# Eleven    11
# Name: First 7 Prime Numbers, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the elements in reverse position

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
print(X[::-1]) #by position
print(X.iloc[::-1]) #by position
# Out:
# Thirteen    13
# Eleven      11
# Seven        7
# Five         5
# Three        3
# Two          2
# One          1
# Name: First 7 Prime Numbers, dtype: int64
# Thirteen    13
# Eleven      11
# Seven        7
# Five         5
# Three        3
# Two          2
# One          1
# Name: First 7 Prime Numbers, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the first and last elements

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
print(X[[0, -1]]) #by position
print(X.iloc[[0, -1]]) #by position
# Out:
# One          1
# Thirteen    13
# Name: First 7 Prime Numbers, dtype: int64
# One          1
# Thirteen    13
# Name: First 7 Prime Numbers, dtype: int64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series manipulation

# %% [markdown]
# ### Convert the given integer pandas Series to float

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
Y = pd.Series(X, dtype=np.float32)
print(X, X.dtype)
print(Y, Y.dtype)
# Out:
# One          1
# Two          2
# Three        3
# Five         5
# Seven        7
# Eleven      11
# Thirteen    13
# Name: First 7 Prime Numbers, dtype: int64 int64
# One          1.0
# Two          2.0
# Three        3.0
# Five         5.0
# Seven        7.0
# Eleven      11.0
# Thirteen    13.0
# Name: First 7 Prime Numbers, dtype: float32 float32

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Order (sort) the given pandas Series

# %%
# your code goes here
X = pd.Series([4,2,5,1,3],
              index=['forth','second','fifth','first','third'])

X.sort_values()
# Out:
# first     1
# second    2
# third     3
# forth     4
# fifth     5
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, set the fifth element equal to 10

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
X[4] = 10
X.rename(index={'Seven':'Ten'}, inplace=True)
X
# Out:
# One          1
# Two          2
# Three        3
# Five         5
# Ten         10
# Eleven      11
# Thirteen    13
# Name: First 7 Prime Numbers, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, change all the middle elements to 0

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
X[1:-1] = 0
X.index=['One','Zero','Zero','Zero','Zero','Zero','Thirteen']
X
# Out:
# One          1
# Zero         0
# Zero         0
# Zero         0
# Zero         0
# Zero         0
# Thirteen    13
# Name: First 7 Prime Numbers, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, add 5 to every element

# %%
# your code goes here
X = pd.Series({'One':1, 'Two':2, 'Three':3, 'Five':5, 'Seven':7, 'Eleven':11, 'Thirteen':13}, name='First 7 Prime Numbers')
X += 5
X
# Out:
# One          6
# Two          7
# Three        8
# Five        10
# Seven       12
# Eleven      16
# Thirteen    18
# Name: First 7 Prime Numbers, dtype: int64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series boolean arrays (also called masks)

# %% [markdown]
# ### Given the X pandas Series, make a mask showing negative elements

# %%
# your code goes here
X = pd.Series([5, 7, -1, 0, -5, 15, -7, 16, 17])
X < 0
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# dtype: bool

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get the negative elements

# %%
# your code goes here
X = pd.Series([5, 7, -1, 0, -5, 15, -7, 16, 17])
X[X < 0]
# Out:
# 2   -1
# 4   -5
# 6   -7
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers higher than 5

# %%
# your code goes here
X = pd.Series([5, 7, -1, 0, -5, 15, -7, 16, 17])
X[X > 5]
# Out:
# 1     7
# 5    15
# 7    16
# 8    17
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers higher than the elements mean

# %%
# your code goes here
X = pd.Series([5, 7, -1, 0, -5, 15, -7, 16, 17])
X[X > X.mean()]
# Out:
# 1     7
# 5    15
# 7    16
# 8    17
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers equal to 2 or 10

# %%
# your code goes here
X = pd.Series([5, 7, -1, 0, -5, 15, -7, 16, 17])
X[(X == 2) | (X == 10)]

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = (X == 2) | (X == 10)
X[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Logic functions

# %% [markdown]
# ### Given the X pandas Series, return True if none of its elements is zero

# %%
# your code goes here

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

X.all()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, return True if any of its elements is zero

# %%
# your code goes here

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

X.any()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Summary statistics

# %% [markdown]
# ### Given the X pandas Series, show the sum of its elements

# %%
# your code goes here

# %%
X = pd.Series([3,5,6,7,2,3,4,9,4])

#np.sum(X)
X.sum()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the mean value of its elements

# %%
# your code goes here

# %%
X = pd.Series([1,2,0,4,5,6,0,0,9,10])

#np.mean(X)
X.mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the max value of its elements

# %%
# your code goes here

# %%
X = pd.Series([1,2,0,4,5,6,0,0,9,10])

#np.max(X)
X.max()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

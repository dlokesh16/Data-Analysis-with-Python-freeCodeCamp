# %%
import numpy as np

# %%
n = 3 # number of bits

# %%
2 ** 3 # 2 ** n is the number of decimal numbers that can be stored
# Out:
# 8

# %%
120

# %%
x = 5

# %%
np.int8
# Out:
# numpy.int8

# %% [markdown]
# ![numpy](numpy.png)
